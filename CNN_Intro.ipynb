# %% [markdown]
# <a href="https://colab.research.google.com/github/nandinib1999/CNN_cifar10_classification/blob/master/CNN_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10

# %matplotlib inline
tf.__version__
# Out:
# TensorFlow 2.x selected.
# '2.0.0-rc2'

# %%
class_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
X_train = X_train/255.0
X_test = X_test/255.0
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)

# %%
model = tf.keras.models.Sequential()

#Adding First Convolutional Layer
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=[32,32,3]))

#Adding Second Convolutional Layer
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu'))

#Adding MaxPool Layer
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

#Adding First Convolutional Layer
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))

#Adding First Convolutional Layer
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))

#Adding MaxPool Layer
model.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2, padding='valid'))

# %%
#Flattening the Convolutional Layers 
model.add(tf.keras.layers.Flatten())

# %%
#Adding a Fully Connected Layer
model.add(tf.keras.layers.Dense(units=128, activation='relu'))

#Adding Output layer
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# ...

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['sparse_categorical_accuracy'])
model.fit(X_train, y_train, epochs=10)
# Out:
# Train on 50000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 19s 376us/sample - loss: 1.3440 - sparse_categorical_accuracy: 0.5165
# Epoch 2/10
# 50000/50000 [==============================] - 15s 291us/sample - loss: 0.8896 - sparse_categorical_accuracy: 0.6894
# Epoch 3/10
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.7202 - sparse_categorical_accuracy: 0.7468
# Epoch 4/10
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.5921 - sparse_categorical_accuracy: 0.7914
# Epoch 5/10
# 50000/50000 [==============================] - 15s 293us/sample - loss: 0.4816 - sparse_categorical_accuracy: 0.8310
# Epoch 6/10
# 50000/50000 [==============================] - 14s 287us/sample - loss: 0.3919 - sparse_categorical_accuracy: 0.8623
# Epoch 7/10
# 50000/50000 [==============================] - 14s 290us/sample - loss: 0.3088 - sparse_categorical_accuracy: 0.8906
# Epoch 8/10
# ...

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print(test_accuracy)
# Out:
# 0.7428
